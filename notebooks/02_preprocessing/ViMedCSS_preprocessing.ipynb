# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# !df -h
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   71G   37G  66% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.3G  696M  65% /usr/sbin/docker-init
# tmpfs           6.4G  7.3M  6.4G   1% /var/colab
# /dev/sda1       114G   84G   31G  74% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive           108G   73G   35G  68% /content/drive

# %%
# %cd /content
# !git clone https://github.com/DuyVuux/Clinical-Ambient-Documentation-Assistant

# %cd Clinical-Ambient-Documentation-Assistant
# !pip install -r requirements.txt
# Out:
# /content
# fatal: destination path 'Clinical-Ambient-Documentation-Assistant' already exists and is not an empty directory.
# /content/Clinical-Ambient-Documentation-Assistant
# WARNING: Ignoring invalid distribution ~andas (/usr/local/lib/python3.12/dist-packages)
# ...
#   Using cached datasets-5.0.0-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# ...
#   Using cached torch-2.12.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (31 kB)
# ...
#   Using cached transformers-5.11.0-py3-none-any.whl.metadata (33 kB)
# ...
#   Using cached chunkformer-1.2.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached jiwer-4.0.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# ...
#   Using cached kaggle-2.2.1-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached nvidia_cublas-13.1.1.3-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# ...

# %%
! git pull
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# Sửa lỗi xung đột phiên bản torch/torchvision
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# WARNING: Ignoring invalid distribution ~andas (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: torch 2.12.0
# Uninstalling torch-2.12.0:
#   Successfully uninstalled torch-2.12.0
# WARNING: Ignoring invalid distribution ~andas (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: torchvision 0.26.0+cpu
# Uninstalling torchvision-0.26.0+cpu:
#   Successfully uninstalled torchvision-0.26.0+cpu
# WARNING: Ignoring invalid distribution ~andas (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: torchaudio 2.11.0+cpu
# Uninstalling torchaudio-2.11.0+cpu:
#   Successfully uninstalled torchaudio-2.11.0+cpu
# WARNING: Ignoring invalid distribution ~andas (/usr/local/lib/python3.12/dist-packages)
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.4/780.4 MB 773.4 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 72.4 MB/s eta 0:00:00
# ...

# %%
# Sử dụng bản 2.5.1+cu121 là bản mới nhất có sẵn trên index cu121
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1 --index-url https://download.pytorch.org/whl/cu121
# !pip install pandas==2.2.2 transformers datasets evaluate jiwer soundfile librosa accelerate
print("\n--- XONG! Vui lòng chọn Runtime -> Restart Session và chạy lại cell Validation ---")
# Out:
# WARNING: Ignoring invalid distribution ~andas (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: torch 2.12.0
# Uninstalling torch-2.12.0:
#   Successfully uninstalled torch-2.12.0
# WARNING: Ignoring invalid distribution ~andas (/usr/local/lib/python3.12/dist-packages)
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Ignoring invalid distribution ~andas (/usr/local/lib/python3.12/dist-packages)
# WARNING: Skipping torchaudio as it is not installed.
# WARNING: Ignoring invalid distribution ~andas (/usr/local/lib/python3.12/dist-packages)
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#   Using cached https://download-r2.pytorch.org/whl/cu121/torch-2.5.1%2Bcu121-cp312-cp312-linux_x86_64.whl (780.4 MB)
# ...
#   Using cached https://download-r2.pytorch.org/whl/cu121/torchvision-0.20.1%2Bcu121-cp312-cp312-linux_x86_64.whl (7.3 MB)
# ...

# %% [markdown]
# Sau khi cài đặt lại xong, hãy thử chạy lại cell đánh giá PhoWhisper ở dưới.

# %%
! HF_TOKEN="***" python scripts/asr_vimedcss/inspect_vimedcss_dataset.py \
  --dataset_id tensorxt/ViMedCSS \
  --output_dir experiments/asr/vimedcss
# Out:
# [INFO] Loading dataset: tensorxt/ViMedCSS
# Resolving data files: 100% 30/30 [00:00<00:00, 9797.49it/s]
# Resolving data files: 100% 30/30 [00:00<00:00, 15521.05it/s]
# Loading dataset shards: 100% 26/26 [00:01<00:00, 14.37it/s]
# [DONE] inventory written
# experiments/asr/vimedcss/data_audit/dataset_inventory.json

# %%
from google.colab import files

# Files to download
files_to_download = [
    '/content/Clinical-Ambient-Documentation-Assistant/experiments/asr/vimedcss/manifests/vimedcss_hard_raw.jsonl',
    '/content/Clinical-Ambient-Documentation-Assistant/experiments/asr/vimedcss/manifests/vimedcss_test_raw.jsonl',
    '/content/Clinical-Ambient-Documentation-Assistant/experiments/asr/vimedcss/manifests/vimedcss_train_raw.jsonl',
    '/content/Clinical-Ambient-Documentation-Assistant/experiments/asr/vimedcss/manifests/vimedcss_validation_raw.jsonl'
]

for file_path in files_to_download:
    try:
        files.download(file_path)
    except Exception as e:
        print(f'Could not download {file_path}: {e}')

# %% [markdown]
# ## Baseline PhoWhisper trên validation/test/hard

# %% [markdown]
# ### Chạy trên validation

# %%
import os
os.environ['HF_TOKEN'] = '***'

# !python scripts/asr_eval/run_whisper_transformers.py \
  --manifest experiments/asr/vimedcss/manifests/vimedcss_validation_raw.jsonl \
  --model vinai/PhoWhisper-medium \
  --output experiments/asr/vimedcss/baseline/phowhisper_medium_validation_predictions.jsonl \
  --language vi \
  --task transcribe
# Out:
# Traceback (most recent call last):
#   File "/content/Clinical-Ambient-Documentation-Assistant/scripts/asr_eval/run_whisper_transformers.py", line 87, in <module>
#     main()
#   File "/content/Clinical-Ambient-Documentation-Assistant/scripts/asr_eval/run_whisper_transformers.py", line 43, in main
#     asr = pipeline(
#           ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/pipelines/__init__.py", line 1033, in pipeline
#     model = load_model(
#             ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py", line 269, in load_model
#     raise ValueError(
# ...

# %% [markdown]
# ### Chạy trên test/hard

# %%
import os
os.chdir('/content/Clinical-Ambient-Documentation-Assistant')
os.environ['TRANSFORMERS_VERIFY_TORCH_LOAD_SAFE'] = 'False'

# Chạy Test
# !export TRANSFORMERS_VERIFY_TORCH_LOAD_SAFE=False && \
 python scripts/asr_eval/run_whisper_transformers.py \
  --manifest experiments/asr/vimedcss/manifests/vimedcss_test_raw.jsonl \
  --model vinai/PhoWhisper-medium \
  --output experiments/asr/vimedcss/baseline/phowhisper_medium_test_predictions.jsonl

# Chạy Hard
# !export TRANSFORMERS_VERIFY_TORCH_LOAD_SAFE=False && \
 python scripts/asr_eval/run_whisper_transformers.py \
  --manifest experiments/asr/vimedcss/manifests/vimedcss_hard_raw.jsonl \
  --model vinai/PhoWhisper-medium \
  --output experiments/asr/vimedcss/baseline/phowhisper_medium_hard_predictions.jsonl
# Out:
# Traceback (most recent call last):
#   File "/content/Clinical-Ambient-Documentation-Assistant/scripts/asr_eval/run_whisper_transformers.py", line 87, in <module>
#     main()
#   File "/content/Clinical-Ambient-Documentation-Assistant/scripts/asr_eval/run_whisper_transformers.py", line 43, in main
#     asr = pipeline(
#           ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/pipelines/__init__.py", line 1033, in pipeline
#     model = load_model(
#             ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py", line 269, in load_model
#     raise ValueError(
# ...

# %% [markdown]
# ### Tính WER

# %%
# !python scripts/asr_eval/compute_wer.py \
  --predictions experiments/asr/vimedcss/baseline/phowhisper_medium_validation_predictions.jsonl \
  --output experiments/asr/vimedcss/baseline/phowhisper_medium_validation_metrics.json

# !python scripts/asr_eval/compute_wer.py \
  --predictions experiments/asr/vimedcss/baseline/phowhisper_medium_test_predictions.jsonl \
  --output experiments/asr/vimedcss/baseline/phowhisper_medium_test_metrics.json

# !python scripts/asr_eval/compute_wer.py \
  --predictions experiments/asr/vimedcss/baseline/phowhisper_medium_hard_predictions.jsonl \
  --output experiments/asr/vimedcss/baseline/phowhisper_medium_hard_metrics.json
# Out:
# Traceback (most recent call last):
#   File "/content/Clinical-Ambient-Documentation-Assistant/scripts/asr_eval/compute_wer.py", line 78, in <module>
#     main()
#   File "/content/Clinical-Ambient-Documentation-Assistant/scripts/asr_eval/compute_wer.py", line 25, in main
#     rows = read_jsonl(Path(args.predictions))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Clinical-Ambient-Documentation-Assistant/scripts/asr_eval/compute_wer.py", line 12, in read_jsonl
#     with path.open("r", encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 1013, in open
#     return io.open(self, mode, buffering, encoding, errors, newline)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'experiments/asr/vimedcss/baseline/phowhisper_medium_validation_predictions.jsonl'
# Traceback (most recent call last):
# ...

# %%
from google.colab import files

# Files to download
files_to_download = [
    'experiments/asr/vimedcss/baseline/phowhisper_medium_validation_predictions.jsonl',
    'experiments/asr/vimedcss/baseline/phowhisper_medium_test_predictions.jsonl',
    'experiments/asr/vimedcss/baseline/phowhisper_medium_hard_predictions.jsonl',
    'experiments/asr/vimedcss/baseline/phowhisper_medium_validation_metrics.json',
    'experiments/asr/vimedcss/baseline/phowhisper_medium_test_metrics.json',
    'experiments/asr/vimedcss/baseline/phowhisper_medium_hard_metrics.json',
    'experiments/asr/vimedcss/baseline/BASELINE_REPORT.md'
]

for file_path in files_to_download:
    try:
        files.download(file_path)
    except Exception as e:
        print(f'Could not download {file_path}: {e}')
